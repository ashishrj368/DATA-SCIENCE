# %%
import pandas as pd
appu=pd.read_csv('dataset1.csv')
print(appu)
# Out:
#            Date Product_Category   Price  Discount Customer_Segment  \
# 0    01-01-2023           Sports  932.80     35.82       Occasional
# 1    02-01-2023             Toys  569.48      3.60          Premium
# 2    03-01-2023       Home Decor  699.68      3.56          Premium
# 3    04-01-2023             Toys  923.27      0.61          Premium
# 4    05-01-2023             Toys  710.17     47.83          Premium
# ..          ...              ...     ...       ...              ...
# 995  22-09-2025          Fashion  740.06     49.06          Regular
# 996  23-09-2025      Electronics  517.10     28.48          Premium
# 997  24-09-2025      Electronics  683.43     12.98       Occasional
# 998  25-09-2025           Sports   51.26     21.85       Occasional
# 999  26-09-2025       Home Decor   93.94     29.68          Regular
#
#      Marketing_Spend  Units_Sold
# 0            6780.38          32
# 1            6807.56          16
# 2            3793.91          27
# ...

# %%
import pandas as pd
kuttappan=pd.read_csv('data1.csv')
print(kuttappan)
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
import pandas as pd
jk=pd.read_csv('data1.csv')
print(jk)
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
import pandas as pd
kd=pd.read_csv('data3.csv')
print(kd)
# Out:
#     tweet_id           user_handle            timestamp  \
# 0        501             @user1068  2025-02-11 08:30:10
# 1        502         @politicsNew2  2025-02-11 09:15:20
# 2        503      @greenVisionary2  2025-02-11 10:05:35
# 3        504        @indieWatcher2  2025-02-11 11:25:40
# 4        505          @libertyFan4  2025-02-11 12:40:50
# 5        506             @user1069  2025-02-12 08:20:15
# 6        507             @taxTalk5  2025-02-12 09:40:30
# 7        508      @sustainability4  2025-02-12 10:30:50
# 8        509     @independantView7  2025-02-12 11:55:20
# 9        510     @freedomAdvocate7  2025-02-12 12:40:50
# 10       511             @user1070  2025-02-13 08:35:25
# 11       512         @marketWatch4  2025-02-13 09:05:55
# 12       513     @greenInitiative4  2025-02-13 10:20:45
# 13       514        @indieSupport4  2025-02-13 11:40:35
# 14       515       @libertyRights4  2025-02-13 12:50:20
# 15       516             @user1071  2025-02-14 08:25:55
# ...

# %%
import pandas as pd
sk=pd.read_csv('data4.csv')
sk
# Out:
#     artist_name                                        track_name  \
# 0        Eminem                                            8 Mile
# 1        Eminem                                        Rabbit Run
# 2        Eminem                                     Lose Yourself
# 3        Eminem                                   Campaign Speech
# 4        Eminem  Chloraseptic (feat. 2 Chainz & Phresher) - Remix
# ..          ...                                               ...
# 531      Eminem                    Guilty Conscience - A Cappella
# 532      Eminem               Tobey (feat. Big Sean and BabyTron)
# 533      Eminem             Venom - Music From The Motion Picture
# 534      Eminem                                     When I'm Gone
# 535      Eminem                      When I'm Gone - Instrumental
#
#                    track_id  \
# 0    5NmL2zxnlt9GiTB2TQbvFM
# 1    30KKYkJ0lonfKI2eaLACnZ
# 2    6GkTKjv1XbFVdI2D8vvDPu
# 3    1DiJsj5a4zBzWSUWdg2nTv
# ...
